# %% [markdown]
# # Preparing CNPJ to ETL process
#
# This notebook aims to generate an intermediate CNPJ file to feed the ETL process. All the unique non-null CNPJ will be exported to an Excel workbook..

# %%
import os
import pandas as pd

# %% [markdown]
# ## 1- Global variables
#
# Absolute paths and file names, both original and export.

# %%
path_abs = 'C:/Users/hbrac/OneDrive/Documentos/GEESC/OSS/Fase 2/Data/Transformed data/'
file_name = 'base_unificada_padronizada.xlsx'
file_export = 'cnpj.xlsx'

# %% [markdown]
# ## 2- Data loading and visualization

# %%
df = pd.read_excel(os.path.join(path_abs, file_name), converters = {'cnpj': str})
df.head()
# Out:
#    uf  municipio     cnes                         nome_estabelecimento  \
# 0  35     355410  9128743  SAMU 192 TAUBATE BASE PIRACANGAGUA AVANCADA
# 1  35     354230  9133232      SAMU 192 TAUBATE BASE REDENCAO DA SERRA
# 2  21     210000  6872174      CENTRO DE MEDICINA ESPECIALIZADA CEMESP
# 3  21     210350  2726645         HOSPITAL REGIONAL DR CARLOS MACIEIRA
# 4  42     421660  2663651                       CENTRO DE SAUDE ROCADO
#
#    tipo_estabelecimento  gestao            cnpj         razao_social  \
# 0                   997       1  99999999999999  SEM NOME REGISTRADO
# 1                   997       1  99999999999999  SEM NOME REGISTRADO
# 2                    16       2  99999999999999  SEM NOME REGISTRADO
# 3                     6       1  99999999999999  SEM NOME REGISTRADO
# 4                     1       1  99999999999999  SEM NOME REGISTRADO
#
#    tipo_entidade  forma_contratacao  ... inicio_vigencia termino_vigencia  \
# 0              1                  1  ...             NaN              NaN
# 1              1                  1  ...             NaN              NaN
# 2              1                  1  ...             NaN              NaN
# 3              1                  1  ...             NaN              NaN
# 4              1                  1  ...             NaN              NaN
#
#   ano_vigencia  valor_contrato  recurso_federal  recurso_estadual  \
# 0       2016.0     999999999.0                9                 9
# 1       2016.0     999999999.0                9                 9
# 2       9999.0     999999999.0                9                 9
# 3       9999.0     999999999.0                9                 9
# 4       9999.0     999999999.0                9                 9
#
#    recurso_municipal  fonte  origem    razao_social_padr
# 0                  9      9       0  SEM NOME REGISTRADO
# 1                  9      9       0  SEM NOME REGISTRADO
# 2                  9      9       0  SEM NOME REGISTRADO
# 3                  9      9       3  SEM NOME REGISTRADO
# 4                  9      9       0  SEM NOME REGISTRADO
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 3- Transformation
#
# The main purpose of this notebbok. The process will be conducted in the following steps.

# %% [markdown]
# ### 3.1- Data filtering
#
# Data will be filtered, removing repeated entries.

# %%
df = df[~((df.razao_social_padr == 'SEM  NOME REGISTRADO')|(df.cnpj == '99999999999999'))]
df = df.drop_duplicates(subset=['cnpj', 'razao_social_padr'], keep = 'first').reset_index(drop = True)

# %% [markdown]
# ### 3.2- Column dropping
#
# Columns that aren't pertinent to this process will be dropped.

# %%
df.drop(columns = ['uf','cnes','inicio_vigencia','ano_vigencia','municipio', 'nome_estabelecimento', 'tipo_estabelecimento', 'gestao', 'razao_social', 'tipo_entidade', 'forma_contratacao', 'termino_vigencia', 'valor_contrato', 'recurso_federal', 'recurso_estadual', 'recurso_municipal', 'fonte', 'origem', 'numero_contrato'], inplace = True)
df.head()
# Out:
#              cnpj                                  razao_social_padr
# 0  42498717008724                                SEM NOME REGISTRADO
# 1  01476404000119                                SEM NOME REGISTRADO
# 2  13363111000104  ASSOCIAÇÃO ASSISTENCIAL À SAÚDE E EDUCAÇÃO SÃO...
# 3  43723907000191                    ASSOCIAÇÃO BENEFICENTE DE APIAÍ
# 4  02812043000105                  ASSOCIAÇÃO COMUNIDADE LUZ DA VIDA

# %% [markdown]
# ## 4 - Export
#
# Data will be exported as an Excel workbook.

# %%
df.to_excel(os.path.join(path_abs, file_export), index = False)
